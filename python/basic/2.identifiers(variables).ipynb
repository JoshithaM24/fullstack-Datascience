# %% [raw]
# Identifiers (OR) Variables
# 1. Identifiers are case-sensitive.
# 2. Identifiers can't having special characters except _
# 3. Identifiers can't start with digits
# 4. Identifiers can be a combination of letters in lowercase (a to z) or uppercase or digits or _

# %%
num = 10            # Identifiers are case sensitive
NUM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 num = 10            # Identifiers are case sensitive
# ----> 2 NUM
#
# NameError: name 'NUM' is not defined

# %%
var2@=10          # Identifiers can't have special characters except _
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 var2@=10          # Identifiers can't have special characters except _
#
# NameError: name 'var2' is not defined

# %%
1var = 10           # Identifiers can't start with digits
# Out:
#   Cell In[6], line 1
#     1var = 10           # Identifiers can't start with digits
#     ^
# SyntaxError: invalid decimal literal

# %%
for = 20            # Keywords or reserved words should not use as identifiers
# Out:
#   Cell In[7], line 1
#     for = 20            # Keywords or reserved words should not use as identifiers
#         ^
# SyntaxError: invalid syntax

# %%
first_name = "josh" # Identifiers can be a combination of letters in lowercase (a to z) or uppercase or digits or _
var1 = "Char"

# %% [raw]
# Keywords (OR) Reserved words
# Total there are 35 keywords in python.
# Except False, True , None remaining all are lowercase
# Category	          Keywords
# Boolean & Null	      True, False, None
# Logical Operators	  and, or, not
# Conditional Flow	  if, elif, else
# Loops & Control	      for, while, break, continue, pass
# Function/Class	      def, return, lambda, class, yield
# Exceptions	         try, except, finally, raise, assert
# Scope & Objects	     global, nonlocal, del, is, in
# Modules	             import, from, as
# Asynchronous	     async, await
# Context Management	 with, as

# %%
#To get list of keywords
import keyword
print(keyword.kwlist)
print(f"Total number of keywords:{len(keyword.kwlist)}")
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Total number of keywords:35

# %% [raw]
# In Python, comments are notes within the source code that the interpreter ignores during execution. They are primarily used to explain logic, improve code readability, and temporarily disable code during debugging.

# %% [raw]
# Types of Comments :
# Single-Line Comments
# These start with a hash symbol (#) and continue until the end of the line. They can be placed on their own line or at the end of a line of code (inline).
# # This is a standalone single-line comment x = 5 # This is an inline comment
# Multi-Line Comments
# Python does not have a dedicated syntax for multi-line comments. Developers typically use one of the following methods:
#
# 1. Consecutive # symbols: Recommended practice (PEP 8).
#
# # This is a multi-line comment # using multiple hash symbols # across lines
#
# 2. Triple-quoted strings (""" or '''): Unassigned string literals are ignored by the interpreter and act like comments.
#
# """ This is a multi-line comment using triple quotes """

# %%
# Single line comment
val1 = 10

# %%
# This is a multi-line comment
# using multiple hash symbols
# across lines
val1 = 10

# %%
# Triple quotes can be used for multiline comments
'''
1. Identifiers should not have special characters except _
2. Identifier should not start with digits
3. Identifiers should not use reserved words
'''
val1 = 10

# %%
""" This is a 
    multi-line comment 
    using triple quotes """
name = "Roja rani"
