# %% [raw]
#   1. Numeric Data Types
# Numeric Type	Description	Examples
# Integer (int)	Whole numbers, positive or negative, without decimals	10, -5
# Floating (float)	Numbers with decimal points or scientific notation	10.5, 3.14
# Complex (complex)	Numbers with a real and an imaginary part, denoted with j	2 + 3j

# %% [markdown]
# 1. Integer

# %%
i = 5   # integer declaration

# %%
type(i)   # Type check
# Out:
# int

# %%
print(i)
# Out:
# 5

# %% [markdown]
# 2. Float

# %%
f = 20.67 # Float declaration

# %%
type(f)   # Type check
# Out:
# float

# %%
print(f)
# Out:
# 20.67

# %% [markdown]
# 3. Complex

# %%
c = 10 + 20J  # can also use j but no other alpabets for imaginary part. It should be j

# %%
type(c)       # Type check
# Out:
# complex

# %%
c.real        # To get real part real attribute need to use
# Out:
# 10.0

# %%
c.imag         # To get imaginary part imag attribute need to use
# Out:
# 20.0

# %% [raw]
# 2. Boolean Data Type
# Type	Description	Values
# Boolean (bool)	Represents logical values	True, False
# 💻 Machines work using 1's and 0's
# True = 1
# False = 0

# %%
f = False     # Boolean False declaration

# %%
t = True      # Boolean True declaration

# %%
type(f)    #type check
# Out:
# bool

# %%
type(t)       # Type check
# Out:
# bool

# %%
print(f)
# Out:
# False

# %%
f + t
# Out:
# 1

# %%
f - t
# Out:
# -1

# %%
f / t
# Out:
# 0.0

# %%
f // t
# Out:
# 0

# %%
f*t
# Out:
# 0

# %% [raw]
# 3. Sequence Types
# Type	         Description	                                    Example
# String (str)	A sequence of Unicode characters enclosed in quotes	"Hello"
# List (list)     An ordered, mutable (changeable) collection that can hold diverse data types	                                                                      [1, "a", 3.5]
# Tuple (tuple)	An ordered, immutable (unchangeable) collection       (1, 2, 3)
# Range (range)	Represents a sequence of numbers, often used in loops	range(1, 5)

# %% [markdown]
# 1. String

# %%
ssq = 'welcome'       # string can be declared in single quotes

# %%
sdq = "welcome"       # string can be declared in double quotes

# %%
stdq = '''welcome to
python programming
language'''            # string can be declared in triple quotes

# %%
type(ssq)              # Type check
# Out:
# str

# %%
type(sdq)
# Out:
# str

# %%
type(stdq)
# Out:
# str

# %%
print(stdq)
# Out:
# welcome to
# python programming
# language

# %%
print(ssq)
# Out:
# welcome
