# %%
3
# Out:
# 3

# %%
5
# Out:
# 5

# %% [raw]
# Arithmetic Operators
# Operation	Operator	Description
# Addition	    +	   Adds two values
# Subtraction  	-      Subtracts the right operand from the left
# Multiplication	*	   Multiplies two values
# Division	    /	   Divides operands and returns a float (e.g., 5 / 2 = 2.5)
# Floor Division	//	   Divides operands and returns an integer, rounding down (e.g., 5 // 2 = 2)
# Modulus	        %	   Returns the remainder of a division (e.g., 5 % 2 = 1)
# Exponentiation	**	   Raises one number to the power of another

# %%
5 + 3 #addtion
# Out:
# 8

# %%
 8 - 3 #sub
# Out:
# 5

# %%
5 * 4     # Multiplication
# Out:
# 20

# %%
8 / 2     # Division
# Out:
# 4.0

# %%
9 // 2    # Floor Division
# Out:
# 4

# %%
3 ** 2    # Exponentiation
# Out:
# 9

# %%
6 % 2     # Modulus
# Out:
# 0

# %% [raw]
# Role of Underscore(_)
# Python automatically stores the value of the last expression in the interpreter to a particular variable called "_."
# We can also assign these value to another variable if you want.

# %%
5 + 4
# Out:
# 9

# %%
_         # stores the result of the above expression
# Out:
# 9

# %%
_ + 6
# Out:
# 15

# %%
a = _     # assigning the value of _ to another variable

# %%
a * 3
# Out:
# 45

# %% [raw]
# BODMAS (or PEMDAS)
#
# BODMAS Rule	Python Operator	Description
# Brackets	()	            Highest priority; forces order
# Orders	   **	                Exponents/Powers
# Division	/, //, %	    Standard, floor division, and remainder
# Multiplication	*	        Multiplication (equal priority with Division)
# Addition	    +	            Addition
# Subtraction  	-	            Subtraction

# %%
4 + 5 - 3 * 10      # (mas - mul,add,sub)
# Out:
# -21

# %%
4 + ( 5 - 10 ) * 3  # BODMAS
# Out:
# -11

# %%
4 / ( 5 - 10 ) * 3  # BODMAS
# Out:
# -2.4000000000000004

# %% [raw]
# Example Calculation
# Expression: 10 + 5 * (2 ** 3) - 6 / 2
#
# Step 1 (Brackets): (2 ** 3) → 8
# Step 2 (Multiplication): 5 * 8 → 40
# Step 3 (Division): 6 / 2 → 3.0
# Step 4 (Addition/Subtraction): 10 + 40 - 3.0 → 50 - 3.0 → 47.0
# Final Answer: 47.0

# %%
10 + 5 * (2 ** 3) - 6 / 2
# Out:
# 47.0
